# %% [markdown]
# # Hierarchical Agent Teams
#
# In our previous example ([Agent Supervisor](../agent_supervisor)), we introduced the concept of a single [supervisor node](https://langchain-ai.github.io/langgraph/concepts/multi_agent/#supervisor) to route work between different worker nodes.
#
# But what if the job for a single worker becomes too complex? What if the number of workers becomes too large?
#
# For some applications, the system may be more effective if work is distributed _hierarchically_.
#
# You can do this by composing different subgraphs and creating a top-level supervisor, along with mid-level supervisors.
#
# To do this, let's build a simple research assistant! The graph will look something like the following:
#
# ![diagram](attachment:38f97bae-8da0-4d98-8fa2-59c52a42e847.png)
#
# This notebook is inspired by the paper [AutoGen: Enabling Next-Gen LLM Applications via Multi-Agent Conversation](https://arxiv.org/abs/2308.08155), by Wu, et. al. In the rest of this notebook, you will:
#
# 1. Define the agents' tools to access the web and write files
# 2. Define some utilities to help create the graph and agents
# 3. Create and define each team (web research + doc writing)
# 4. Compose everything together.
#
# ## Setup
#
# First, let's install our required packages and set our API keys

# %%
# %%capture --no-stderr
# %pip install -U langgraph langchain_community langchain_anthropic langchain_experimental

# %%
import getpass
import os


def _set_if_undefined(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"Please provide your {var}")


_set_if_undefined("OPENAI_API_KEY")
_set_if_undefined("TAVILY_API_KEY")

# %% [markdown]
# <div class="admonition tip">
#     <p class="admonition-title">Set up <a href="https://smith.langchain.com">LangSmith</a> for LangGraph development</p>
#     <p style="padding-top: 5px;">
#         Sign up for LangSmith to quickly spot issues and improve the performance of your LangGraph projects. LangSmith lets you use trace data to debug, test, and monitor your LLM apps built with LangGraph — read more about how to get started <a href="https://docs.smith.langchain.com">here</a>.
#     </p>
# </div>

# %% [markdown]
# ## Create Tools
#
# Each team will be composed of one or more agents each with one or more tools. Below, define all the tools to be used by your different teams.
#
# We'll start with the research team.
#
# **ResearchTeam tools**
#
# The research team can use a search engine and url scraper to find information on the web. Feel free to add additional functionality below to boost the team performance!

# %%
from typing import Annotated, List

from langchain_community.document_loaders import WebBaseLoader
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.tools import tool

tavily_tool = TavilySearchResults(max_results=5)


@tool
def scrape_webpages(urls: List[str]) -> str:
    """Use requests and bs4 to scrape the provided web pages for detailed information."""
    loader = WebBaseLoader(urls)
    docs = loader.load()
    return "\n\n".join(
        [
            f'<Document name="{doc.metadata.get("title", "")}">\n{doc.page_content}\n</Document>'
            for doc in docs
        ]
    )
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# **Document writing team tools**
#
# Next up, we will give some tools for the doc writing team to use.
# We define some bare-bones file-access tools below.
#
# Note that this gives the agents access to your file-system, which can be unsafe. We also haven't optimized the tool descriptions for performance.

# %%
from pathlib import Path
from tempfile import TemporaryDirectory
from typing import Dict, Optional

from langchain_experimental.utilities import PythonREPL
from typing_extensions import TypedDict

_TEMP_DIRECTORY = TemporaryDirectory()
WORKING_DIRECTORY = Path(_TEMP_DIRECTORY.name)


@tool
def create_outline(
    points: Annotated[List[str], "List of main points or sections."],
    file_name: Annotated[str, "File path to save the outline."],
) -> Annotated[str, "Path of the saved outline file."]:
    """Create and save an outline."""
    with (WORKING_DIRECTORY / file_name).open("w") as file:
        for i, point in enumerate(points):
            file.write(f"{i + 1}. {point}\n")
    return f"Outline saved to {file_name}"


@tool
def read_document(
    file_name: Annotated[str, "File path to read the document from."],
    start: Annotated[Optional[int], "The start line. Default is 0"] = None,
    end: Annotated[Optional[int], "The end line. Default is None"] = None,
) -> str:
    """Read the specified document."""
    with (WORKING_DIRECTORY / file_name).open("r") as file:
        lines = file.readlines()
    if start is not None:
        start = 0
    return "\n".join(lines[start:end])


@tool
def write_document(
    content: Annotated[str, "Text content to be written into the document."],
    file_name: Annotated[str, "File path to save the document."],
) -> Annotated[str, "Path of the saved document file."]:
    """Create and save a text document."""
    with (WORKING_DIRECTORY / file_name).open("w") as file:
        file.write(content)
    return f"Document saved to {file_name}"


@tool
def edit_document(
    file_name: Annotated[str, "Path of the document to be edited."],
    inserts: Annotated[
        Dict[int, str],
        "Dictionary where key is the line number (1-indexed) and value is the text to be inserted at that line.",
    ],
) -> Annotated[str, "Path of the edited document file."]:
    """Edit a document by inserting text at specific line numbers."""

    with (WORKING_DIRECTORY / file_name).open("r") as file:
        lines = file.readlines()

    sorted_inserts = sorted(inserts.items())

    for line_number, text in sorted_inserts:
        if 1 <= line_number <= len(lines) + 1:
            lines.insert(line_number - 1, text + "\n")
        else:
            return f"Error: Line number {line_number} is out of range."

    with (WORKING_DIRECTORY / file_name).open("w") as file:
        file.writelines(lines)

    return f"Document edited and saved to {file_name}"


# Warning: This executes code locally, which can be unsafe when not sandboxed

repl = PythonREPL()


@tool
def python_repl_tool(
    code: Annotated[str, "The python code to execute to generate your chart."],
):
    """Use this to execute python code. If you want to see the output of a value,
    you should print it out with `print(...)`. This is visible to the user."""
    try:
        result = repl.run(code)
    except BaseException as e:
        return f"Failed to execute. Error: {repr(e)}"
    return f"Successfully executed:\n```python\n{code}\n```\nStdout: {result}"

# %% [markdown]
# ## Helper Utilities
#
# We are going to create a few utility functions to make it more concise when we want to:
#
# 1. Create a worker agent.
# 2. Create a supervisor for the sub-graph.
#
# These will simplify the graph compositional code at the end for us so it's easier to see what's going on.

# %% [markdown]
# ## Define Agent Teams
#
# Now we can get to define our hierarchical teams. "Choose your player!"
#
# ### Research Team
#
# The research team will have a search agent and a web scraping "research_agent" as the two worker nodes. Let's create those, as well as the team supervisor.

# %%
from langgraph.prebuilt.chat_agent_executor import AgentRouterState, make_agent_node, add_entrypoint_router
from langgraph.prebuilt.handoff import handoff

# %%
from langchain_openai import ChatOpenAI

# %%
model = ChatOpenAI(model="gpt-4o", model_kwargs=dict(parallel_tool_calls=False))

# %%
from langgraph.checkpoint.memory import MemorySaver

# %%
@tool
def search(query: str):
    """Search the web"""
    return "Taylor Swift is touring in Nov 2024"

# %%
def keep_last_message(state):
    return {**state, "messages": [HumanMessage(content=state["messages"][-1].content)]}

# %%
from langgraph.graph import StateGraph, START

# %%
builder = StateGraph(AgentRouterState)

search_agent_tool = handoff("search", tool_message="Transferred to search agent", name="transfer_to_search", description="Call search to do web search")
web_scraper_agent_tool = handoff("web_scraper", tool_message="Transferred to web scraper agent", name="transfer_to_web_scraper", description="Call web scraper to read a website")

supervisor = make_agent_node(
    model, 
    [search_agent_tool, web_scraper_agent_tool],
    state_schema=AgentRouterState,
    state_modifier="You are a supervisor tasked with managing a conversation between the following workers: ['search', 'web_scraper']."
)
search_agent = make_agent_node(model, [tavily_tool], state_schema=AgentRouterState, output_processor=keep_last_message)
web_scraper_agent = make_agent_node(model, [scrape_webpages], state_schema=AgentRouterState, output_processor=keep_last_message)

builder.add_node("supervisor", supervisor)
builder.add_node("search", search_agent)
builder.add_node("web_scraper", web_scraper_agent)
builder.add_edge(START, "supervisor")
# add explicit edges back to the supervisor
builder.add_edge("search", "supervisor")
builder.add_edge("web_scraper", "supervisor")
memory = MemorySaver()
research_graph = builder.compile(checkpointer=memory)

# %%
from langchain_core.messages import HumanMessage

# %% [markdown]
# Now that we've created the necessary components, defining their interactions is easy. Add the nodes to the team graph, and define the edges, which determine the transition criteria.

# %%
from IPython.display import Image, display

display(Image(research_graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# We can give this team work directly. Try it out below.

# %%
config = {"configurable": {"thread_id": "1"}}

# %%
for s in research_graph.stream(
    {"messages": [("user", "when is Taylor Swift's next tour?")]},
    config,
):
    print(s)
    print("---")
# Out:
# {'supervisor': {'messages': [HumanMessage(content="when is Taylor Swift's next tour?", additional_kwargs={}, response_metadata={}, id='78c53262-87ce-4425-909c-47d84a5bb612'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_liQN4cvJO0IzlnLOtXizzKp5', 'function': {'arguments': '{}', 'name': 'transfer_to_search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 89, 'total_tokens': 100, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_831e067d82', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d75d78ec-7ad0-411d-8112-26c2d0af8ba2-0', tool_calls=[{'name': 'transfer_to_search', 'args': {}, 'id': 'call_liQN4cvJO0IzlnLOtXizzKp5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 89, 'output_tokens': 11, 'total_tokens': 100, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to search agent', name='transfer_to_search', id='6042ce6a-589a-4bb0-bb26-abe4b39d30f3', tool_call_id='call_liQN4cvJO0IzlnLOtXizzKp5', artifact=Command(goto='search'))], 'node': 'search'}}
# ---
# {'search': {'messages': [HumanMessage(content="Taylor Swift's next tour, the Eras Tour, will continue in 2024. Here are some of the upcoming dates and locations:\n\n- **October 18, 2024**: Hard Rock Stadium, Miami Gardens, FL, USA\n- **November 14, 2024**: Concerts in Canada (specific locations to be announced)\n- **December 8, 2024**: BC Place, Vancouver, Canada\n\nFor more details about specific dates and locations, you can visit [Taylor Swift's official tour page](https://www.taylorswift.com/tour/) or check ticket platforms like Ticketmaster.", additional_kwargs={}, response_metadata={}, id='9bb32d0c-6bb7-48ac-af00-6bf85d8cdccd')], 'node': 'search'}}
# ---
# {'supervisor': {'messages': [HumanMessage(content="when is Taylor Swift's next tour?", additional_kwargs={}, response_metadata={}, id='78c53262-87ce-4425-909c-47d84a5bb612'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_liQN4cvJO0IzlnLOtXizzKp5', 'function': {'arguments': '{}', 'name': 'transfer_to_search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 89, 'total_tokens': 100, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_831e067d82', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d75d78ec-7ad0-411d-8112-26c2d0af8ba2-0', tool_calls=[{'name': 'transfer_to_search', 'args': {}, 'id': 'call_liQN4cvJO0IzlnLOtXizzKp5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 89, 'output_tokens': 11, 'total_tokens': 100, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to search agent', name='transfer_to_search', id='6042ce6a-589a-4bb0-bb26-abe4b39d30f3', tool_call_id='call_liQN4cvJO0IzlnLOtXizzKp5', artifact=Command(goto='search')), HumanMessage(content="Taylor Swift's next tour, the Eras Tour, will continue in 2024. Here are some of the upcoming dates and locations:\n\n- **October 18, 2024**: Hard Rock Stadium, Miami Gardens, FL, USA\n- **November 14, 2024**: Concerts in Canada (specific locations to be announced)\n- **December 8, 2024**: BC Place, Vancouver, Canada\n\nFor more details about specific dates and locations, you can visit [Taylor Swift's official tour page](https://www.taylorswift.com/tour/) or check ticket platforms like Ticketmaster.", additional_kwargs={}, response_metadata={}, id='9bb32d0c-6bb7-48ac-af00-6bf85d8cdccd'), AIMessage(content="Taylor Swift's next tour, the Eras Tour, will continue in 2024 with some of the upcoming dates and locations as follows:\n\n- **October 18, 2024**: Hard Rock Stadium, Miami Gardens, FL, USA\n- **November 14, 2024**: Concerts in Canada (specific locations to be announced)\n- **December 8, 2024**: BC Place, Vancouver, Canada\n\nFor more detailed information about specific dates and locations, you can visit [Taylor Swift's official tour page](https://www.taylorswift.com/tour/) or check ticket platforms like Ticketmaster.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 133, 'prompt_tokens': 248, 'total_tokens': 381, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'stop', 'logprobs': None}, id='run-852fc9bf-8d1a-497e-b706-8650c78e1013-0', usage_metadata={'input_tokens': 248, 'output_tokens': 133, 'total_tokens': 381, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'node': 'search'}}
# ---

# %%
research_graph.get_state(config).values["messages"]
# Out:
# [HumanMessage(content="when is Taylor Swift's next tour?", additional_kwargs={}, response_metadata={}, id='78c53262-87ce-4425-909c-47d84a5bb612'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_liQN4cvJO0IzlnLOtXizzKp5', 'function': {'arguments': '{}', 'name': 'transfer_to_search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 89, 'total_tokens': 100, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_831e067d82', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d75d78ec-7ad0-411d-8112-26c2d0af8ba2-0', tool_calls=[{'name': 'transfer_to_search', 'args': {}, 'id': 'call_liQN4cvJO0IzlnLOtXizzKp5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 89, 'output_tokens': 11, 'total_tokens': 100, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='Transferred to search agent', name='transfer_to_search', id='6042ce6a-589a-4bb0-bb26-abe4b39d30f3', tool_call_id='call_liQN4cvJO0IzlnLOtXizzKp5', artifact={'update': None, 'send': [], 'resume': None, 'goto': 'search'}),
#  HumanMessage(content="Taylor Swift's next tour, the Eras Tour, will continue in 2024. Here are some of the upcoming dates and locations:\n\n- **October 18, 2024**: Hard Rock Stadium, Miami Gardens, FL, USA\n- **November 14, 2024**: Concerts in Canada (specific locations to be announced)\n- **December 8, 2024**: BC Place, Vancouver, Canada\n\nFor more details about specific dates and locations, you can visit [Taylor Swift's official tour page](https://www.taylorswift.com/tour/) or check ticket platforms like Ticketmaster.", additional_kwargs={}, response_metadata={}, id='9bb32d0c-6bb7-48ac-af00-6bf85d8cdccd'),
#  AIMessage(content="Taylor Swift's next tour, the Eras Tour, will continue in 2024 with some of the upcoming dates and locations as follows:\n\n- **October 18, 2024**: Hard Rock Stadium, Miami Gardens, FL, USA\n- **November 14, 2024**: Concerts in Canada (specific locations to be announced)\n- **December 8, 2024**: BC Place, Vancouver, Canada\n\nFor more detailed information about specific dates and locations, you can visit [Taylor Swift's official tour page](https://www.taylorswift.com/tour/) or check ticket platforms like Ticketmaster.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 133, 'prompt_tokens': 248, 'total_tokens': 381, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'stop', 'logprobs': None}, id='run-852fc9bf-8d1a-497e-b706-8650c78e1013-0', usage_metadata={'input_tokens': 248, 'output_tokens': 133, 'total_tokens': 381, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %% [markdown]
# ### Document Writing Team
#
# Create the document writing team below using a similar approach. This time, we will give each agent access to different file-writing tools.
#
# Note that we are giving file-system access to our agent here, which is not safe in all cases.

# %%
doc_writer_tool = handoff("doc_writer", tool_message="Transferred to doc writer", name="transfer_to_doc_writer", description="Write documents")
note_taker_tool = handoff("note_taker", tool_message="Transferred to note taker", name="transfer_to_note_taker", description="Create outlines")
chart_generator_tool = handoff("chart_generator", tool_message="Transferred to chart generator", name="transfer_to_chart_generator", description="Generate charts")

doc_writing_supervisor = make_agent_node(
    model, 
    [doc_writer_tool, note_taker_tool, chart_generator_tool],
    state_schema=AgentRouterState,
    state_modifier='You are a supervisor tasked with managing a conversation between the following workers: ["doc_writer", "note_taker", "chart_generator"].'
)
doc_writer_agent = make_agent_node(
    model,
    [write_document, edit_document, read_document],
    output_processor=keep_last_message,
    state_schema=AgentRouterState,
    state_modifier="You can read, write and edit documents based on note-taker's outlines. Don't ask follow-up questions."
)
note_taking_agent = make_agent_node(
    model, 
    [create_outline, read_document],
    state_schema=AgentRouterState,
    output_processor=keep_last_message, 
    state_modifier="You can read documents and create outlines for the document writer. Don't ask follow-up questions."
)
chart_generating_agent = make_agent_node(
    model, 
    [read_document, python_repl_tool],
    state_schema=AgentRouterState,
    output_processor=keep_last_message,
)

# Create the graph here
paper_writing_builder = StateGraph(AgentRouterState)
paper_writing_builder.add_node("supervisor", doc_writing_supervisor)
paper_writing_builder.add_node("doc_writer", doc_writer_agent)
paper_writing_builder.add_node("note_taker", note_taking_agent)
paper_writing_builder.add_node("chart_generator", chart_generating_agent)

# Define the control flow
paper_writing_builder.add_edge(START, "supervisor")
# We want our workers to ALWAYS "report back" to the supervisor when done
paper_writing_builder.add_edge("doc_writer", "supervisor")
paper_writing_builder.add_edge("note_taker", "supervisor")
paper_writing_builder.add_edge("chart_generator", "supervisor")

memory = MemorySaver()
paper_writing_graph = paper_writing_builder.compile(checkpointer=memory)

# %% [markdown]
# With the objects themselves created, we can form the graph.

# %%
from IPython.display import Image, display

display(Image(paper_writing_graph.get_graph().draw_mermaid_png()))

# %%
for s in paper_writing_graph.stream(
    {
        "messages": [
            (
                "user",
                "Write an outline for poem about cats and then write the poem to disk.",
            )
        ]
    },
    config
):
    print(s)
    print("---")
# Out:
# {'supervisor': {'messages': [HumanMessage(content='Write an outline for poem about cats and then write the poem to disk.', additional_kwargs={}, response_metadata={}, id='971c1b7f-6b9a-4344-bd7c-6d1ca0a44e60'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_R9ctgaUjxPh6Hc59CIod4TUF', 'function': {'arguments': '{}', 'name': 'transfer_to_note_taker'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 106, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-b592bf75-8318-43d9-906e-35c34a4d8bd2-0', tool_calls=[{'name': 'transfer_to_note_taker', 'args': {}, 'id': 'call_R9ctgaUjxPh6Hc59CIod4TUF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 106, 'output_tokens': 13, 'total_tokens': 119, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to note taker', name='transfer_to_note_taker', id='ab94053e-ed0d-4bc1-b9c5-9553ccfe4ba0', tool_call_id='call_R9ctgaUjxPh6Hc59CIod4TUF', artifact=Command(goto='note_taker'))], 'node': 'note_taker'}}
# ---
# {'note_taker': {'messages': [HumanMessage(content='I have created and saved an outline for a poem about cats. You can find it in the file "poem_outline.txt".', additional_kwargs={}, response_metadata={}, id='949234ed-3210-4cbd-8a31-118d175e7c11')], 'node': 'note_taker'}}
# ---
# {'supervisor': {'messages': [HumanMessage(content='Write an outline for poem about cats and then write the poem to disk.', additional_kwargs={}, response_metadata={}, id='971c1b7f-6b9a-4344-bd7c-6d1ca0a44e60'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_R9ctgaUjxPh6Hc59CIod4TUF', 'function': {'arguments': '{}', 'name': 'transfer_to_note_taker'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 106, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-b592bf75-8318-43d9-906e-35c34a4d8bd2-0', tool_calls=[{'name': 'transfer_to_note_taker', 'args': {}, 'id': 'call_R9ctgaUjxPh6Hc59CIod4TUF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 106, 'output_tokens': 13, 'total_tokens': 119, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to note taker', name='transfer_to_note_taker', id='ab94053e-ed0d-4bc1-b9c5-9553ccfe4ba0', tool_call_id='call_R9ctgaUjxPh6Hc59CIod4TUF', artifact=Command(goto='note_taker')), HumanMessage(content='I have created and saved an outline for a poem about cats. You can find it in the file "poem_outline.txt".', additional_kwargs={}, response_metadata={}, id='949234ed-3210-4cbd-8a31-118d175e7c11'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_LaVdIcmmrDCjKNKLoQZW6wtp', 'function': {'arguments': '{}', 'name': 'transfer_to_doc_writer'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 165, 'total_tokens': 177, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-3dd463a5-e6f2-406c-b0eb-92d6f42ab305-0', tool_calls=[{'name': 'transfer_to_doc_writer', 'args': {}, 'id': 'call_LaVdIcmmrDCjKNKLoQZW6wtp', 'type': 'tool_call'}], usage_metadata={'input_tokens': 165, 'output_tokens': 12, 'total_tokens': 177, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to doc writer', name='transfer_to_doc_writer', id='c5de7fe4-8cc2-4a14-bf13-c85775e164c8', tool_call_id='call_LaVdIcmmrDCjKNKLoQZW6wtp', artifact=Command(goto='doc_writer'))], 'node': 'doc_writer'}}
# ---
# {'doc_writer': {'messages': [HumanMessage(content='I have written the poem based on the outline and saved it as "Ode_to_the_Feline_Mystique.txt".', additional_kwargs={}, response_metadata={}, id='f9cc2955-a38a-4c87-8c32-0ecb50d60048')], 'node': 'doc_writer'}}
# ---
# {'supervisor': {'messages': [HumanMessage(content='Write an outline for poem about cats and then write the poem to disk.', additional_kwargs={}, response_metadata={}, id='971c1b7f-6b9a-4344-bd7c-6d1ca0a44e60'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_R9ctgaUjxPh6Hc59CIod4TUF', 'function': {'arguments': '{}', 'name': 'transfer_to_note_taker'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 106, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-b592bf75-8318-43d9-906e-35c34a4d8bd2-0', tool_calls=[{'name': 'transfer_to_note_taker', 'args': {}, 'id': 'call_R9ctgaUjxPh6Hc59CIod4TUF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 106, 'output_tokens': 13, 'total_tokens': 119, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to note taker', name='transfer_to_note_taker', id='ab94053e-ed0d-4bc1-b9c5-9553ccfe4ba0', tool_call_id='call_R9ctgaUjxPh6Hc59CIod4TUF', artifact=Command(goto='note_taker')), HumanMessage(content='I have created and saved an outline for a poem about cats. You can find it in the file "poem_outline.txt".', additional_kwargs={}, response_metadata={}, id='949234ed-3210-4cbd-8a31-118d175e7c11'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_LaVdIcmmrDCjKNKLoQZW6wtp', 'function': {'arguments': '{}', 'name': 'transfer_to_doc_writer'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 165, 'total_tokens': 177, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-3dd463a5-e6f2-406c-b0eb-92d6f42ab305-0', tool_calls=[{'name': 'transfer_to_doc_writer', 'args': {}, 'id': 'call_LaVdIcmmrDCjKNKLoQZW6wtp', 'type': 'tool_call'}], usage_metadata={'input_tokens': 165, 'output_tokens': 12, 'total_tokens': 177, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to doc writer', name='transfer_to_doc_writer', id='c5de7fe4-8cc2-4a14-bf13-c85775e164c8', tool_call_id='call_LaVdIcmmrDCjKNKLoQZW6wtp', artifact=Command(goto='doc_writer')), HumanMessage(content='I have written the poem based on the outline and saved it as "Ode_to_the_Feline_Mystique.txt".', additional_kwargs={}, response_metadata={}, id='f9cc2955-a38a-4c87-8c32-0ecb50d60048'), AIMessage(content='The outline and the poem have been successfully created and saved. Is there anything else you would like to do with the poem or any other task you need assistance with?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 220, 'total_tokens': 254, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'stop', 'logprobs': None}, id='run-50f8d34f-5bf5-4231-8cda-879d8e604c2a-0', usage_metadata={'input_tokens': 220, 'output_tokens': 34, 'total_tokens': 254, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'node': 'doc_writer'}}
# ---

# %%
WORKING_DIRECTORY
# Out:
# PosixPath('/var/folders/8w/jvdn7fb12sq4656f16qs8w9h0000gn/T/tmpkiye4f9d')

# %% [markdown]
# ## Add Layers
#
# In this design, we are enforcing a top-down planning policy. We've created two graphs already, but we have to decide how to route work between the two.
#
# We'll create a _third_ graph to orchestrate the previous two, and add some connectors to define how this top-level state is shared between the different graphs.

# %%
llm = ChatOpenAI(model="gpt-4o", model_kwargs=dict(parallel_tool_calls=False))

research_team_tool = handoff("research_team", tool_message="Transferred to research team", name="transfer_to_research_team", description="Transfer to research team")
paper_writing_team_tool = handoff("writing_team", tool_message="Transferred to writing team", name="transfer_to_writing_team", description="Transfer to writing team")

teams_supervisor_node = make_agent_node(
    llm, 
    [research_team_tool, paper_writing_team_tool], 
    state_schema=AgentRouterState,
    state_modifier="You are a supervisor tasked with managing a conversation between the following teams: ['research_team', 'writing_team']."
)


def call_research_team(state: AgentRouterState) -> AgentRouterState:
    # might actually need to pass full state here
    last_message_before_transfer = state["messages"][-3]
    response = research_graph.invoke({"messages": last_message_before_transfer})
    return {
        "messages": [
            HumanMessage(content=response["messages"][-1].content, name="research_team")
        ]
    }


def call_paper_writing_team(state: AgentRouterState) -> AgentRouterState:
    # might actually need to pass full state here
    last_message_before_transfer = state["messages"][-3]
    response = paper_writing_graph.invoke({"messages": last_message_before_transfer})
    return {
        "messages": [
            HumanMessage(content=response["messages"][-1].content, name="writing_team")
        ]
    }


# Define the graph.
super_builder = StateGraph(AgentRouterState)
super_builder.add_node("supervisor", teams_supervisor_node)
super_builder.add_node("research_team", call_research_team)
super_builder.add_node("writing_team", call_paper_writing_team)

# Define the control flow
super_builder.add_edge(START, "supervisor")
# We want our teams to ALWAYS "report back" to the top-level supervisor when done
super_builder.add_edge("research_team", "supervisor")
super_builder.add_edge("writing_team", "supervisor")
memory = MemorySaver()
super_graph = super_builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display

display(Image(super_graph.get_graph().draw_mermaid_png()))

# %%
# super_graph.get_state(config).values["messages"]

# %%
for s in super_graph.stream(
    {
        "messages": [
            ("user", "Research AI agents and write a brief report about them.")
        ],
    },
    config,
    subgraphs=True
):
    print(s)
    print("---")
# Out:
# (('supervisor:49653300-335a-2b86-deb3-b7a31d254118',), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0XxzeKxefqyzG14Qzoyhr2g4', 'function': {'arguments': '{}', 'name': 'transfer_to_research_team'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 647, 'total_tokens': 660, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e8425c90-1453-476e-8667-de824d39f1ae-0', tool_calls=[{'name': 'transfer_to_research_team', 'args': {}, 'id': 'call_0XxzeKxefqyzG14Qzoyhr2g4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 647, 'output_tokens': 13, 'total_tokens': 660, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# (('supervisor:49653300-335a-2b86-deb3-b7a31d254118',), {'tools': {'messages': [ToolMessage(content='Transferred to research team', name='transfer_to_research_team', id='8ac01fa4-160f-402b-a2dd-c4efb98eb900', tool_call_id='call_0XxzeKxefqyzG14Qzoyhr2g4', artifact=Command(goto='research_team'))]}})
# ---
# ((), {'supervisor': {'messages': [HumanMessage(content='Research AI agents and write a brief report about them.', additional_kwargs={}, response_metadata={}, id='72c4b4ba-f047-40ba-9065-6e6c7e998a46'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_F8huo5jaEB90hKc7mTAFfOQf', 'function': {'arguments': '{}', 'name': 'transfer_to_research_team'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 89, 'total_tokens': 102, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-21127ba8-f493-4b2e-befd-adb97f019d72-0', tool_calls=[{'name': 'transfer_to_research_team', 'args': {}, 'id': 'call_F8huo5jaEB90hKc7mTAFfOQf', 'type': 'tool_call'}], usage_metadata={'input_tokens': 89, 'output_tokens': 13, 'total_tokens': 102, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to research team', name='transfer_to_research_team', id='a5647636-ce23-4611-8bbb-81e08195b64d', tool_call_id='call_F8huo5jaEB90hKc7mTAFfOQf', artifact={'update': None, 'send': [], 'resume': None, 'goto': 'research_team'}), HumanMessage(content='The report provides a comprehensive overview of AI agents as of 2023, highlighting their growing importance in various sectors due to their ability to operate autonomously or semi-autonomously. Here’s a brief summary of the key points:\n\n1. **Types and Applications:**\n   - AI agents are divided into single-agent and multi-agent systems. Single-agent systems handle tasks like customer service or acting as virtual assistants, while multi-agent systems tackle complex, interrelated operations such as those in a smart factory.\n   - In healthcare, AI agents support medical professionals by managing routine tasks, allowing more focus on direct patient care.\n\n2. **Technological Integration:**\n   - Large language models and advancements in generative AI are being incorporated into these agents, improving their natural language processing capabilities and task performance.\n\n3. **Market Trends:**\n   - The market for AI agents is expanding, fueled by the demand for personalized customer interaction and operational efficiency. Companies use AI agents for tailored recommendations, effective support, and strategic marketing.\n\n4. **Challenges and Future Prospects:**\n   - Challenges include ensuring compatibility across platforms and ecosystems for seamless operation. While promising productivity and efficiency gains, fully autonomous AI operations are still under exploration.\n   - The future might witness deeper integration of AI agents into everyday technologies, potentially revolutionizing various industry operations.\n\nAI agents are poised to transform sectors by boosting efficiencies and personalizing interactions, but overcoming technological and integration challenges is essential for their widespread adoption and full autonomy.', additional_kwargs={}, response_metadata={}, name='research_team', id='c98483f6-a589-434a-ba93-b9124029a46a'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_fHC6GGUxb7C9ukOGB1FPD6PD', 'function': {'arguments': '{}', 'name': 'transfer_to_writing_team'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 420, 'total_tokens': 433, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run- ...
# ---
# (('research_team:5be43cf6-998c-aeda-108c-39a25a3e831c', 'supervisor:811a29b4-6f20-afc2-c233-2569c8a0001f'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_VXa5pHnmxeQR1BAVN3vqTAzm', 'function': {'arguments': '{}', 'name': 'transfer_to_search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 92, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-dba5ff3c-b86a-48c1-a282-e5ba58892fd9-0', tool_calls=[{'name': 'transfer_to_search', 'args': {}, 'id': 'call_VXa5pHnmxeQR1BAVN3vqTAzm', 'type': 'tool_call'}], usage_metadata={'input_tokens': 92, 'output_tokens': 11, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# (('research_team:5be43cf6-998c-aeda-108c-39a25a3e831c', 'supervisor:811a29b4-6f20-afc2-c233-2569c8a0001f'), {'tools': {'messages': [ToolMessage(content='Transferred to search agent', name='transfer_to_search', id='59e9b124-79b3-4122-88a6-a03c0a265f04', tool_call_id='call_VXa5pHnmxeQR1BAVN3vqTAzm', artifact=Command(goto='search'))]}})
# ---
# (('research_team:5be43cf6-998c-aeda-108c-39a25a3e831c',), {'supervisor': {'messages': [HumanMessage(content='Research AI agents and write a brief report about them.', additional_kwargs={}, response_metadata={}, id='296fe28a-bba3-4495-aad2-f57592d58bdf'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_VXa5pHnmxeQR1BAVN3vqTAzm', 'function': {'arguments': '{}', 'name': 'transfer_to_search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 92, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-dba5ff3c-b86a-48c1-a282-e5ba58892fd9-0', tool_calls=[{'name': 'transfer_to_search', 'args': {}, 'id': 'call_VXa5pHnmxeQR1BAVN3vqTAzm', 'type': 'tool_call'}], usage_metadata={'input_tokens': 92, 'output_tokens': 11, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to search agent', name='transfer_to_search', id='59e9b124-79b3-4122-88a6-a03c0a265f04', tool_call_id='call_VXa5pHnmxeQR1BAVN3vqTAzm', artifact=Command(goto='search'))], 'node': 'search'}})
# ---
# (('research_team:5be43cf6-998c-aeda-108c-39a25a3e831c', 'search:eb56ea4b-b43d-68c4-1159-4c8d4647afb6'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_e0RwHA0fSuI5C7CbeXm40b19', 'function': {'arguments': '{"query":"AI agents 2023"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 114, 'total_tokens': 136, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9e15ccd6a4', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d5f5a22f-d58b-4dae-8b1d-20c81ee2feee-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'AI agents 2023'}, 'id': 'call_e0RwHA0fSuI5C7CbeXm40b19', 'type': 'tool_call'}], usage_metadata={'input_tokens': 114, 'output_tokens': 22, 'total_tokens': 136, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# (('research_team:5be43cf6-998c-aeda-108c-39a25a3e831c', 'search:eb56ea4b-b43d-68c4-1159-4c8d4647afb6'), {'tools': {'messages': [ToolMessage(content='[{"url": "https://www2.deloitte.com/us/en/insights/industry/technology/technology-media-and-telecom-predictions/2025/autonomous-generative-ai-agents-still-under-development.html", "content": "Autonomous gen AI agents—agentic AI—could increase the productivity of knowledge workers and make workflows of all kinds more efficient. But the \\"autonomous\\" part may take time for wide adoption. ... growing 0.8% from 1987 to 2023 and only 0.5% from 2019 to 2023. 16 In most OECD countries,"}, {"url": "https://www.grandviewresearch.com/industry-analysis/ai-agents-market-report", "content": "AI Agents Market Size, Share And Growth Report, 2030 AI Agents Market Size, Share And Growth Report, 2030 AI Agents Market Size, Share & Trends Analysis Report By Technology, By Agent System (Single-agent, Multi-agent), By Type, By Application (Customer Service & Virtual Assistants, Healthcare), By End Use, By Region, And Segment Forecasts, 2024 - 2030 Consumers expect more personalized interactions, and AI agents enable businesses to deliver customized solutions by leveraging data to provide targeted recommendations, customer support, and marketing outreach, increasing customer satisfaction and loyalty. U.S., Canada, Mexico, Germany, U.K., France, China, India, Japan, Australia, South Korea, Brazil, UAE, South Africa, KSA Global AI Agents Market Report Segmentation For this study, Grand View Research has segmented the global AI agents market report based on the technology, agent system, type, application, end use, and region."}, {"url": "https://www.taskade.com/blog/top-autonomous-agents/", "content": "🐑🤖\\nCategorized in:\\nShare Article:\\nRelated Articles\\nTable of ContentsToggle Table of ContentToggle\\nLike what you read?\\nSubscribe to our email newsletter to get the latest posts delivered right to your email. Visit the repo page to learn more: https://github.com/microsoft/autogen\\nMetaGPT\\nMetaGPT is another framework for open-source AI agents that attempts to imitate the structure of a traditional software company. A (relatively ) hands-free AI experience.\\n💡 AI Agent Trivia: The concept of autonomous AI agents came to life with a paper titled “Task-Driven Autonomous Agent” published in early 2023 by Yohei Nakajima, general partner at Untapped Capital.\\n Visit the repo page to learn more: https://github.com/microsoft/JARVIS\\nOpenAGI\\nOpenAGI is an open-source AGI (artificial general intelligence) research platform combining small, expert models — models tailored for tasks like sentiment analysis or image deblurring — and Reinforcement Learning from Task Feedback (RLTF) for improving their output.\\n The Python script is only 140 words of code and, according to the official GitHub repo, “uses OpenAI and vector databases such as Chroma or Weaviate to create, prioritize, and execute tasks.”\\n"}, {"url": "https://www.newsweek.com/microsoft-pushes-autonomous-ai-agents-amid-industry-caution-1988254", "content": "Microsoft\'s pitch centers on AI agents as more than just chatbots. The Microsoft logo is displayed outside its French headquarters in Issy-les-Moulineaux, outside Paris, May 13, 2024."}, {"url": "https://www.gartner.com/en/articles/what-s-new-in-artificial-intelligence-from-the-2023-gartner-hype-cycle", "content": "jsbacContactjsbacContact\\n8 a.m. – 7 p.m. ET\\n8 a.m.\xa0– 5 p.m. GMT\\nMonday through Friday\\nPlease provide the consent below\\nI have read, understood and accepted Gartner\\nSeparate Consent Letter\\n, whereby I agree (1) to provide Gartner with my personal information, and understand that information will be transferred outside of mainland China and processed by Gartner group companies and other legitimate processing parties and (2) to be contacted by Gartner group\\ncompanies via internet, mobile/telephone and email, for the purposes of sales, marketing and research ...
# ---
# (('research_team:5be43cf6-998c-aeda-108c-39a25a3e831c', 'search:eb56ea4b-b43d-68c4-1159-4c8d4647afb6'), {'agent': {'messages': [AIMessage(content='AI agents, particularly in 2023, have become a focal point in the realm of artificial intelligence, with diverse applications and growing market interest. These agents are software entities that perform tasks autonomously, often utilizing AI technologies like machine learning and natural language processing to interact with users and systems intelligently.\n\n### Key Developments and Trends\n\n1. **Autonomous AI Agents**: The concept of autonomous generative AI agents, often referred to as "agentic AI," has been gaining traction. These agents are designed to enhance productivity by automating workflows and supporting knowledge workers. However, achieving full autonomy in AI agents is still under development and may take time for widespread adoption [Deloitte](https://www2.deloitte.com/us/en/insights/industry/technology/technology-media-and-telecom-predictions/2025/autonomous-generative-ai-agents-still-under-development.html).\n\n2. **Market Growth and Applications**: The AI agents market is growing, driven by demand for personalized customer interactions. AI agents are prevalent in customer service, virtual assistance, and healthcare, where they deliver customized solutions and improve customer satisfaction. The market is segmented by technology, agent system (single-agent vs. multi-agent), type, application, end-use, and region [Grand View Research](https://www.grandviewresearch.com/industry-analysis/ai-agents-market-report).\n\n3. **Emergence of Open-Source AI Agents**: Platforms like MetaGPT and OpenAGI are emerging as frameworks for developing open-source AI agents. These platforms aim to mimic organizational structures and improve AI capabilities through methods like Reinforcement Learning from Task Feedback (RLTF) [Taskade Blog](https://www.taskade.com/blog/top-autonomous-agents/).\n\n4. **Microsoft\'s Initiatives**: Microsoft has been actively promoting AI agents beyond traditional chatbots, focusing on more autonomous and versatile applications. This move aligns with broader industry trends towards embedding AI into more complex decision-making processes [Newsweek](https://www.newsweek.com/microsoft-pushes-autonomous-ai-agents-amid-industry-caution-1988254).\n\n5. **Technological Advancements**: AI simulation, which involves the combination of AI and simulation technologies, is key to developing and training AI agents. This innovation is part of the broader generative AI advancements that include popular technologies like stable diffusion and large language models [Gartner](https://www.gartner.com/en/articles/what-s-new-in-artificial-intelligence-from-the-2023-gartner-hype-cycle).\n\nIn summary, AI agents are evolving rapidly, with significant advancements in autonomy, market application, and technological integration. These agents are poised to transform various industries by enhancing operational efficiencies and enabling more personalized user experiences.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 554, 'prompt_tokens': 1257, 'total_tokens': 1811, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'stop', 'logprobs': None}, id='run-201bf368-4f61-4542-8aca-1c37801c1959-0', usage_metadata={'input_tokens': 1257, 'output_tokens': 554, 'total_tokens': 1811, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# (('research_team:5be43cf6-998c-aeda-108c-39a25a3e831c',), {'search': {'messages': [HumanMessage(content='AI agents, particularly in 2023, have become a focal point in the realm of artificial intelligence, with diverse applications and growing market interest. These agents are software entities that perform tasks autonomously, often utilizing AI technologies like machine learning and natural language processing to interact with users and systems intelligently.\n\n### Key Developments and Trends\n\n1. **Autonomous AI Agents**: The concept of autonomous generative AI agents, often referred to as "agentic AI," has been gaining traction. These agents are designed to enhance productivity by automating workflows and supporting knowledge workers. However, achieving full autonomy in AI agents is still under development and may take time for widespread adoption [Deloitte](https://www2.deloitte.com/us/en/insights/industry/technology/technology-media-and-telecom-predictions/2025/autonomous-generative-ai-agents-still-under-development.html).\n\n2. **Market Growth and Applications**: The AI agents market is growing, driven by demand for personalized customer interactions. AI agents are prevalent in customer service, virtual assistance, and healthcare, where they deliver customized solutions and improve customer satisfaction. The market is segmented by technology, agent system (single-agent vs. multi-agent), type, application, end-use, and region [Grand View Research](https://www.grandviewresearch.com/industry-analysis/ai-agents-market-report).\n\n3. **Emergence of Open-Source AI Agents**: Platforms like MetaGPT and OpenAGI are emerging as frameworks for developing open-source AI agents. These platforms aim to mimic organizational structures and improve AI capabilities through methods like Reinforcement Learning from Task Feedback (RLTF) [Taskade Blog](https://www.taskade.com/blog/top-autonomous-agents/).\n\n4. **Microsoft\'s Initiatives**: Microsoft has been actively promoting AI agents beyond traditional chatbots, focusing on more autonomous and versatile applications. This move aligns with broader industry trends towards embedding AI into more complex decision-making processes [Newsweek](https://www.newsweek.com/microsoft-pushes-autonomous-ai-agents-amid-industry-caution-1988254).\n\n5. **Technological Advancements**: AI simulation, which involves the combination of AI and simulation technologies, is key to developing and training AI agents. This innovation is part of the broader generative AI advancements that include popular technologies like stable diffusion and large language models [Gartner](https://www.gartner.com/en/articles/what-s-new-in-artificial-intelligence-from-the-2023-gartner-hype-cycle).\n\nIn summary, AI agents are evolving rapidly, with significant advancements in autonomy, market application, and technological integration. These agents are poised to transform various industries by enhancing operational efficiencies and enabling more personalized user experiences.', additional_kwargs={}, response_metadata={}, id='d56ccff7-14f8-4202-a306-265b09f2674b')], 'node': 'search'}})
# ---
# (('research_team:5be43cf6-998c-aeda-108c-39a25a3e831c', 'supervisor:2c82e80b-2a9e-1e82-e893-4854decd8d89'), {'agent': {'messages': [AIMessage(content='AI agents have become a significant focus in the field of artificial intelligence in 2023, with a range of applications and increasing market interest. These agents are software entities that autonomously perform tasks, often using AI technologies like machine learning and natural language processing to intelligently interact with users and systems.\n\n### Key Developments and Trends\n\n1. **Autonomous AI Agents**: The idea of autonomous generative AI agents, or "agentic AI," is gaining momentum. These agents are intended to boost productivity by automating workflows and assisting knowledge workers. However, the development of fully autonomous AI agents is ongoing and may take time to achieve widespread adoption.\n\n2. **Market Growth and Applications**: The AI agents market is expanding due to the demand for personalized customer interactions. AI agents are commonly used in customer service, virtual assistance, and healthcare to provide customized solutions and enhance customer satisfaction. The market is segmented by technology, agent system (single-agent vs. multi-agent), type, application, end-use, and region.\n\n3. **Emergence of Open-Source AI Agents**: New platforms like MetaGPT and OpenAGI are emerging as frameworks for creating open-source AI agents. These platforms aim to replicate organizational structures and improve AI capabilities through methods such as Reinforcement Learning from Task Feedback (RLTF).\n\n4. **Microsoft\'s Initiatives**: Microsoft is actively promoting AI agents beyond traditional chatbots, focusing on more autonomous and versatile applications. This aligns with broader industry trends towards embedding AI into more complex decision-making processes.\n\n5. **Technological Advancements**: AI simulation, which combines AI and simulation technologies, is crucial for developing and training AI agents. This is part of the broader generative AI advancements, including popular technologies like stable diffusion and large language models.\n\nIn summary, AI agents are rapidly evolving, with significant advancements in autonomy, market application, and technological integration. These agents are set to transform various industries by enhancing operational efficiencies and providing more personalized user experiences.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 397, 'prompt_tokens': 673, 'total_tokens': 1070, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_831e067d82', 'finish_reason': 'stop', 'logprobs': None}, id='run-53ba1661-9b9f-462b-aff5-a4a67e754dd2-0', usage_metadata={'input_tokens': 673, 'output_tokens': 397, 'total_tokens': 1070, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# (('research_team:5be43cf6-998c-aeda-108c-39a25a3e831c',), {'supervisor': {'messages': [HumanMessage(content='Research AI agents and write a brief report about them.', additional_kwargs={}, response_metadata={}, id='296fe28a-bba3-4495-aad2-f57592d58bdf'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_VXa5pHnmxeQR1BAVN3vqTAzm', 'function': {'arguments': '{}', 'name': 'transfer_to_search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 92, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-dba5ff3c-b86a-48c1-a282-e5ba58892fd9-0', tool_calls=[{'name': 'transfer_to_search', 'args': {}, 'id': 'call_VXa5pHnmxeQR1BAVN3vqTAzm', 'type': 'tool_call'}], usage_metadata={'input_tokens': 92, 'output_tokens': 11, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to search agent', name='transfer_to_search', id='59e9b124-79b3-4122-88a6-a03c0a265f04', tool_call_id='call_VXa5pHnmxeQR1BAVN3vqTAzm', artifact=Command(goto='search')), HumanMessage(content='AI agents, particularly in 2023, have become a focal point in the realm of artificial intelligence, with diverse applications and growing market interest. These agents are software entities that perform tasks autonomously, often utilizing AI technologies like machine learning and natural language processing to interact with users and systems intelligently.\n\n### Key Developments and Trends\n\n1. **Autonomous AI Agents**: The concept of autonomous generative AI agents, often referred to as "agentic AI," has been gaining traction. These agents are designed to enhance productivity by automating workflows and supporting knowledge workers. However, achieving full autonomy in AI agents is still under development and may take time for widespread adoption [Deloitte](https://www2.deloitte.com/us/en/insights/industry/technology/technology-media-and-telecom-predictions/2025/autonomous-generative-ai-agents-still-under-development.html).\n\n2. **Market Growth and Applications**: The AI agents market is growing, driven by demand for personalized customer interactions. AI agents are prevalent in customer service, virtual assistance, and healthcare, where they deliver customized solutions and improve customer satisfaction. The market is segmented by technology, agent system (single-agent vs. multi-agent), type, application, end-use, and region [Grand View Research](https://www.grandviewresearch.com/industry-analysis/ai-agents-market-report).\n\n3. **Emergence of Open-Source AI Agents**: Platforms like MetaGPT and OpenAGI are emerging as frameworks for developing open-source AI agents. These platforms aim to mimic organizational structures and improve AI capabilities through methods like Reinforcement Learning from Task Feedback (RLTF) [Taskade Blog](https://www.taskade.com/blog/top-autonomous-agents/).\n\n4. **Microsoft\'s Initiatives**: Microsoft has been actively promoting AI agents beyond traditional chatbots, focusing on more autonomous and versatile applications. This move aligns with broader industry trends towards embedding AI into more complex decision-making processes [Newsweek](https://www.newsweek.com/microsoft-pushes-autonomous-ai-agents-amid-industry-caution-1988254).\n\n5. **Technological Advancements**: AI simulation, which involves the combination of AI and simulation technologies, is key to developing and training AI agents. This innovation is part of the broader generative AI advancements that include popular technologies like stable diffusion and large language models [Gartner](https://ww ...
# ---
# ((), {'research_team': {'messages': [HumanMessage(content='AI agents have become a significant focus in the field of artificial intelligence in 2023, with a range of applications and increasing market interest. These agents are software entities that autonomously perform tasks, often using AI technologies like machine learning and natural language processing to intelligently interact with users and systems.\n\n### Key Developments and Trends\n\n1. **Autonomous AI Agents**: The idea of autonomous generative AI agents, or "agentic AI," is gaining momentum. These agents are intended to boost productivity by automating workflows and assisting knowledge workers. However, the development of fully autonomous AI agents is ongoing and may take time to achieve widespread adoption.\n\n2. **Market Growth and Applications**: The AI agents market is expanding due to the demand for personalized customer interactions. AI agents are commonly used in customer service, virtual assistance, and healthcare to provide customized solutions and enhance customer satisfaction. The market is segmented by technology, agent system (single-agent vs. multi-agent), type, application, end-use, and region.\n\n3. **Emergence of Open-Source AI Agents**: New platforms like MetaGPT and OpenAGI are emerging as frameworks for creating open-source AI agents. These platforms aim to replicate organizational structures and improve AI capabilities through methods such as Reinforcement Learning from Task Feedback (RLTF).\n\n4. **Microsoft\'s Initiatives**: Microsoft is actively promoting AI agents beyond traditional chatbots, focusing on more autonomous and versatile applications. This aligns with broader industry trends towards embedding AI into more complex decision-making processes.\n\n5. **Technological Advancements**: AI simulation, which combines AI and simulation technologies, is crucial for developing and training AI agents. This is part of the broader generative AI advancements, including popular technologies like stable diffusion and large language models.\n\nIn summary, AI agents are rapidly evolving, with significant advancements in autonomy, market application, and technological integration. These agents are set to transform various industries by enhancing operational efficiencies and providing more personalized user experiences.', additional_kwargs={}, response_metadata={}, name='research_team')]}})
# ---
# (('supervisor:7ab7a995-3a0e-bd21-ee87-6cd05b96ee18',), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_cwZ0C4f8iapjRB3cCsooGoHV', 'function': {'arguments': '{}', 'name': 'transfer_to_writing_team'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 1078, 'total_tokens': 1091, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-28922340-d797-404c-8c52-73ca42113c77-0', tool_calls=[{'name': 'transfer_to_writing_team', 'args': {}, 'id': 'call_cwZ0C4f8iapjRB3cCsooGoHV', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1078, 'output_tokens': 13, 'total_tokens': 1091, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# (('supervisor:7ab7a995-3a0e-bd21-ee87-6cd05b96ee18',), {'tools': {'messages': [ToolMessage(content='Transferred to writing team', name='transfer_to_writing_team', id='e75282a1-813d-4875-b3ab-ea9a6f896264', tool_call_id='call_cwZ0C4f8iapjRB3cCsooGoHV', artifact=Command(goto='writing_team'))]}})
# ---
# ((), {'supervisor': {'messages': [HumanMessage(content='Research AI agents and write a brief report about them.', additional_kwargs={}, response_metadata={}, id='72c4b4ba-f047-40ba-9065-6e6c7e998a46'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_F8huo5jaEB90hKc7mTAFfOQf', 'function': {'arguments': '{}', 'name': 'transfer_to_research_team'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 89, 'total_tokens': 102, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-21127ba8-f493-4b2e-befd-adb97f019d72-0', tool_calls=[{'name': 'transfer_to_research_team', 'args': {}, 'id': 'call_F8huo5jaEB90hKc7mTAFfOQf', 'type': 'tool_call'}], usage_metadata={'input_tokens': 89, 'output_tokens': 13, 'total_tokens': 102, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to research team', name='transfer_to_research_team', id='a5647636-ce23-4611-8bbb-81e08195b64d', tool_call_id='call_F8huo5jaEB90hKc7mTAFfOQf', artifact={'update': None, 'send': [], 'resume': None, 'goto': 'research_team'}), HumanMessage(content='The report provides a comprehensive overview of AI agents as of 2023, highlighting their growing importance in various sectors due to their ability to operate autonomously or semi-autonomously. Here’s a brief summary of the key points:\n\n1. **Types and Applications:**\n   - AI agents are divided into single-agent and multi-agent systems. Single-agent systems handle tasks like customer service or acting as virtual assistants, while multi-agent systems tackle complex, interrelated operations such as those in a smart factory.\n   - In healthcare, AI agents support medical professionals by managing routine tasks, allowing more focus on direct patient care.\n\n2. **Technological Integration:**\n   - Large language models and advancements in generative AI are being incorporated into these agents, improving their natural language processing capabilities and task performance.\n\n3. **Market Trends:**\n   - The market for AI agents is expanding, fueled by the demand for personalized customer interaction and operational efficiency. Companies use AI agents for tailored recommendations, effective support, and strategic marketing.\n\n4. **Challenges and Future Prospects:**\n   - Challenges include ensuring compatibility across platforms and ecosystems for seamless operation. While promising productivity and efficiency gains, fully autonomous AI operations are still under exploration.\n   - The future might witness deeper integration of AI agents into everyday technologies, potentially revolutionizing various industry operations.\n\nAI agents are poised to transform sectors by boosting efficiencies and personalizing interactions, but overcoming technological and integration challenges is essential for their widespread adoption and full autonomy.', additional_kwargs={}, response_metadata={}, name='research_team', id='c98483f6-a589-434a-ba93-b9124029a46a'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_fHC6GGUxb7C9ukOGB1FPD6PD', 'function': {'arguments': '{}', 'name': 'transfer_to_writing_team'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 420, 'total_tokens': 433, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run- ...
# ---
# (('writing_team:71560c9a-b3e1-4274-2603-913b4bd53cf4', 'supervisor:628ae914-dc34-705b-a916-ebfed1aa5e65'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_X48goXZvCJ70UX0yFSoplURT', 'function': {'arguments': '{}', 'name': 'transfer_to_doc_writer'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 490, 'total_tokens': 502, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-dc119b42-5c3b-4b86-818e-5eb44127e9a7-0', tool_calls=[{'name': 'transfer_to_doc_writer', 'args': {}, 'id': 'call_X48goXZvCJ70UX0yFSoplURT', 'type': 'tool_call'}], usage_metadata={'input_tokens': 490, 'output_tokens': 12, 'total_tokens': 502, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# (('writing_team:71560c9a-b3e1-4274-2603-913b4bd53cf4', 'supervisor:628ae914-dc34-705b-a916-ebfed1aa5e65'), {'tools': {'messages': [ToolMessage(content='Transferred to doc writer', name='transfer_to_doc_writer', id='7120807d-c081-41fb-b660-eeb3334c1e31', tool_call_id='call_X48goXZvCJ70UX0yFSoplURT', artifact=Command(goto='doc_writer'))]}})
# ---
# (('writing_team:71560c9a-b3e1-4274-2603-913b4bd53cf4',), {'supervisor': {'messages': [HumanMessage(content='AI agents have become a significant focus in the field of artificial intelligence in 2023, with a range of applications and increasing market interest. These agents are software entities that autonomously perform tasks, often using AI technologies like machine learning and natural language processing to intelligently interact with users and systems.\n\n### Key Developments and Trends\n\n1. **Autonomous AI Agents**: The idea of autonomous generative AI agents, or "agentic AI," is gaining momentum. These agents are intended to boost productivity by automating workflows and assisting knowledge workers. However, the development of fully autonomous AI agents is ongoing and may take time to achieve widespread adoption.\n\n2. **Market Growth and Applications**: The AI agents market is expanding due to the demand for personalized customer interactions. AI agents are commonly used in customer service, virtual assistance, and healthcare to provide customized solutions and enhance customer satisfaction. The market is segmented by technology, agent system (single-agent vs. multi-agent), type, application, end-use, and region.\n\n3. **Emergence of Open-Source AI Agents**: New platforms like MetaGPT and OpenAGI are emerging as frameworks for creating open-source AI agents. These platforms aim to replicate organizational structures and improve AI capabilities through methods such as Reinforcement Learning from Task Feedback (RLTF).\n\n4. **Microsoft\'s Initiatives**: Microsoft is actively promoting AI agents beyond traditional chatbots, focusing on more autonomous and versatile applications. This aligns with broader industry trends towards embedding AI into more complex decision-making processes.\n\n5. **Technological Advancements**: AI simulation, which combines AI and simulation technologies, is crucial for developing and training AI agents. This is part of the broader generative AI advancements, including popular technologies like stable diffusion and large language models.\n\nIn summary, AI agents are rapidly evolving, with significant advancements in autonomy, market application, and technological integration. These agents are set to transform various industries by enhancing operational efficiencies and providing more personalized user experiences.', additional_kwargs={}, response_metadata={}, name='research_team', id='47e1cddb-a5ff-4999-8cfa-4b680db0cc58'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_X48goXZvCJ70UX0yFSoplURT', 'function': {'arguments': '{}', 'name': 'transfer_to_doc_writer'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 490, 'total_tokens': 502, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-dc119b42-5c3b-4b86-818e-5eb44127e9a7-0', tool_calls=[{'name': 'transfer_to_doc_writer', 'args': {}, 'id': 'call_X48goXZvCJ70UX0yFSoplURT', 'type': 'tool_call'}], usage_metadata={'input_tokens': 490, 'output_tokens': 12, 'total_tokens': 502, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to doc writer', name='transfer_to_doc_writer', id='7120807d-c081-41fb-b660-eeb3334c1e31', tool_call_id='call_X48goXZvCJ70UX0yFSoplURT', artifact=Command(goto='doc_writer'))], 'node': 'doc_writer'}})
# ---
# (('writing_team:71560c9a-b3e1-4274-2603-913b4bd53cf4', 'doc_writer:b6faed05-a9f5-c475-5240-5b2a9b426e20'), {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_qxMrECcdMvByijVzQLzEb69b', 'function': {'arguments': '{"content":"AI agents have become a significant focus in the field of artificial intelligence in 2023, with a range of applications and increasing market interest. These agents are software entities that autonomously perform tasks, often using AI technologies like machine learning and natural language processing to intelligently interact with users and systems.\\n\\n### Key Developments and Trends\\n\\n1. **Autonomous AI Agents**: The idea of autonomous generative AI agents, or \\"agentic AI,\\" is gaining momentum. These agents are intended to boost productivity by automating workflows and assisting knowledge workers. However, the development of fully autonomous AI agents is ongoing and may take time to achieve widespread adoption.\\n\\n2. **Market Growth and Applications**: The AI agents market is expanding due to the demand for personalized customer interactions. AI agents are commonly used in customer service, virtual assistance, and healthcare to provide customized solutions and enhance customer satisfaction. The market is segmented by technology, agent system (single-agent vs. multi-agent), type, application, end-use, and region.\\n\\n3. **Emergence of Open-Source AI Agents**: New platforms like MetaGPT and OpenAGI are emerging as frameworks for creating open-source AI agents. These platforms aim to replicate organizational structures and improve AI capabilities through methods such as Reinforcement Learning from Task Feedback (RLTF).\\n\\n4. **Microsoft\'s Initiatives**: Microsoft is actively promoting AI agents beyond traditional chatbots, focusing on more autonomous and versatile applications. This aligns with broader industry trends towards embedding AI into more complex decision-making processes.\\n\\n5. **Technological Advancements**: AI simulation, which combines AI and simulation technologies, is crucial for developing and training AI agents. This is part of the broader generative AI advancements, including popular technologies like stable diffusion and large language models.\\n\\nIn summary, AI agents are rapidly evolving, with significant advancements in autonomy, market application, and technological integration. These agents are set to transform various industries by enhancing operational efficiencies and providing more personalized user experiences.","file_name":"AI_Agents_2023_Research_Report.txt"}', 'name': 'write_document'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 436, 'prompt_tokens': 617, 'total_tokens': 1053, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-038d5e21-a3e8-43cb-aad2-939bca56178a-0', tool_calls=[{'name': 'write_document', 'args': {'content': 'AI agents have become a significant focus in the field of artificial intelligence in 2023, with a range of applications and increasing market interest. These agents are software entities that autonomously perform tasks, often using AI technologies like machine learning and natural language processing to intelligently interact with users and systems.\n\n### Key Developments and Trends\n\n1. **Autonomous AI Agents**: The idea of autonomous generative AI agents, or "agentic AI," is gaining momentum. These agents are intended to boost productivity by automating workflows and assisting knowledge workers. However, the development of fully autonomous AI agents is ongoing and may take time to achieve widespread adoption.\n\n2. **Market Growth and Applications**: The AI a ...
# ---
# (('writing_team:71560c9a-b3e1-4274-2603-913b4bd53cf4', 'doc_writer:b6faed05-a9f5-c475-5240-5b2a9b426e20'), {'tools': {'messages': [ToolMessage(content='Document saved to AI_Agents_2023_Research_Report.txt', name='write_document', id='7a30289b-e5cb-4f4b-9140-55937a6602d7', tool_call_id='call_qxMrECcdMvByijVzQLzEb69b')]}})
# ---
# (('writing_team:71560c9a-b3e1-4274-2603-913b4bd53cf4', 'doc_writer:b6faed05-a9f5-c475-5240-5b2a9b426e20'), {'agent': {'messages': [AIMessage(content='The document titled "AI_Agents_2023_Research_Report.txt" has been created and saved.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1075, 'total_tokens': 1098, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'stop', 'logprobs': None}, id='run-9755af9d-050c-4a77-9b1b-7c1eca06a1b2-0', usage_metadata={'input_tokens': 1075, 'output_tokens': 23, 'total_tokens': 1098, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# (('writing_team:71560c9a-b3e1-4274-2603-913b4bd53cf4',), {'doc_writer': {'messages': [HumanMessage(content='The document titled "AI_Agents_2023_Research_Report.txt" has been created and saved.', additional_kwargs={}, response_metadata={}, id='ba8b9856-f0a3-4c7a-ba4e-598b770e769c')], 'node': 'doc_writer'}})
# ---
# (('writing_team:71560c9a-b3e1-4274-2603-913b4bd53cf4', 'supervisor:b39f37dc-e86e-c5be-cf8f-36578de60afc'), {'agent': {'messages': [AIMessage(content='Great! The document titled "AI_Agents_2023_Research_Report.txt" has been successfully created and saved. If you need further assistance or have additional tasks, let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 542, 'total_tokens': 582, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'stop', 'logprobs': None}, id='run-0c4388cc-ead2-402c-95bc-c232c3f7c2ce-0', usage_metadata={'input_tokens': 542, 'output_tokens': 40, 'total_tokens': 582, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# (('writing_team:71560c9a-b3e1-4274-2603-913b4bd53cf4',), {'supervisor': {'messages': [HumanMessage(content='AI agents have become a significant focus in the field of artificial intelligence in 2023, with a range of applications and increasing market interest. These agents are software entities that autonomously perform tasks, often using AI technologies like machine learning and natural language processing to intelligently interact with users and systems.\n\n### Key Developments and Trends\n\n1. **Autonomous AI Agents**: The idea of autonomous generative AI agents, or "agentic AI," is gaining momentum. These agents are intended to boost productivity by automating workflows and assisting knowledge workers. However, the development of fully autonomous AI agents is ongoing and may take time to achieve widespread adoption.\n\n2. **Market Growth and Applications**: The AI agents market is expanding due to the demand for personalized customer interactions. AI agents are commonly used in customer service, virtual assistance, and healthcare to provide customized solutions and enhance customer satisfaction. The market is segmented by technology, agent system (single-agent vs. multi-agent), type, application, end-use, and region.\n\n3. **Emergence of Open-Source AI Agents**: New platforms like MetaGPT and OpenAGI are emerging as frameworks for creating open-source AI agents. These platforms aim to replicate organizational structures and improve AI capabilities through methods such as Reinforcement Learning from Task Feedback (RLTF).\n\n4. **Microsoft\'s Initiatives**: Microsoft is actively promoting AI agents beyond traditional chatbots, focusing on more autonomous and versatile applications. This aligns with broader industry trends towards embedding AI into more complex decision-making processes.\n\n5. **Technological Advancements**: AI simulation, which combines AI and simulation technologies, is crucial for developing and training AI agents. This is part of the broader generative AI advancements, including popular technologies like stable diffusion and large language models.\n\nIn summary, AI agents are rapidly evolving, with significant advancements in autonomy, market application, and technological integration. These agents are set to transform various industries by enhancing operational efficiencies and providing more personalized user experiences.', additional_kwargs={}, response_metadata={}, name='research_team', id='47e1cddb-a5ff-4999-8cfa-4b680db0cc58'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_X48goXZvCJ70UX0yFSoplURT', 'function': {'arguments': '{}', 'name': 'transfer_to_doc_writer'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 490, 'total_tokens': 502, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-dc119b42-5c3b-4b86-818e-5eb44127e9a7-0', tool_calls=[{'name': 'transfer_to_doc_writer', 'args': {}, 'id': 'call_X48goXZvCJ70UX0yFSoplURT', 'type': 'tool_call'}], usage_metadata={'input_tokens': 490, 'output_tokens': 12, 'total_tokens': 502, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to doc writer', name='transfer_to_doc_writer', id='7120807d-c081-41fb-b660-eeb3334c1e31', tool_call_id='call_X48goXZvCJ70UX0yFSoplURT', artifact=Command(goto='doc_writer')), HumanMessage(content='The document titled "AI_Agents_2023_Research_Report.txt" has been created and saved.', additional_kwargs={}, response_metadata={}, id='ba8b9856-f0a3-4c7a-ba4e-598b770e769c'), AIMessage(content='Great! The document titled "AI_Agents_2023_Research_Report.txt" has been successful ...
# ---
# ((), {'writing_team': {'messages': [HumanMessage(content='Great! The document titled "AI_Agents_2023_Research_Report.txt" has been successfully created and saved. If you need further assistance or have additional tasks, let me know!', additional_kwargs={}, response_metadata={}, name='writing_team')]}})
# ---
# (('supervisor:527e3eef-c285-6d63-84f2-3c349227b0e2',), {'agent': {'messages': [AIMessage(content="Excellent teamwork! If there's anything else you need or another task to tackle, feel free to ask.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 1152, 'total_tokens': 1173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'stop', 'logprobs': None}, id='run-46691605-c594-4d99-8b59-7ca1aeeae804-0', usage_metadata={'input_tokens': 1152, 'output_tokens': 21, 'total_tokens': 1173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}})
# ---
# ((), {'supervisor': {'messages': [HumanMessage(content='Research AI agents and write a brief report about them.', additional_kwargs={}, response_metadata={}, id='72c4b4ba-f047-40ba-9065-6e6c7e998a46'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_F8huo5jaEB90hKc7mTAFfOQf', 'function': {'arguments': '{}', 'name': 'transfer_to_research_team'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 89, 'total_tokens': 102, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-21127ba8-f493-4b2e-befd-adb97f019d72-0', tool_calls=[{'name': 'transfer_to_research_team', 'args': {}, 'id': 'call_F8huo5jaEB90hKc7mTAFfOQf', 'type': 'tool_call'}], usage_metadata={'input_tokens': 89, 'output_tokens': 13, 'total_tokens': 102, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Transferred to research team', name='transfer_to_research_team', id='a5647636-ce23-4611-8bbb-81e08195b64d', tool_call_id='call_F8huo5jaEB90hKc7mTAFfOQf', artifact={'update': None, 'send': [], 'resume': None, 'goto': 'research_team'}), HumanMessage(content='The report provides a comprehensive overview of AI agents as of 2023, highlighting their growing importance in various sectors due to their ability to operate autonomously or semi-autonomously. Here’s a brief summary of the key points:\n\n1. **Types and Applications:**\n   - AI agents are divided into single-agent and multi-agent systems. Single-agent systems handle tasks like customer service or acting as virtual assistants, while multi-agent systems tackle complex, interrelated operations such as those in a smart factory.\n   - In healthcare, AI agents support medical professionals by managing routine tasks, allowing more focus on direct patient care.\n\n2. **Technological Integration:**\n   - Large language models and advancements in generative AI are being incorporated into these agents, improving their natural language processing capabilities and task performance.\n\n3. **Market Trends:**\n   - The market for AI agents is expanding, fueled by the demand for personalized customer interaction and operational efficiency. Companies use AI agents for tailored recommendations, effective support, and strategic marketing.\n\n4. **Challenges and Future Prospects:**\n   - Challenges include ensuring compatibility across platforms and ecosystems for seamless operation. While promising productivity and efficiency gains, fully autonomous AI operations are still under exploration.\n   - The future might witness deeper integration of AI agents into everyday technologies, potentially revolutionizing various industry operations.\n\nAI agents are poised to transform sectors by boosting efficiencies and personalizing interactions, but overcoming technological and integration challenges is essential for their widespread adoption and full autonomy.', additional_kwargs={}, response_metadata={}, name='research_team', id='c98483f6-a589-434a-ba93-b9124029a46a'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_fHC6GGUxb7C9ukOGB1FPD6PD', 'function': {'arguments': '{}', 'name': 'transfer_to_writing_team'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 420, 'total_tokens': 433, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7f6be3efb0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run- ...
# ---
